# %% [markdown]
# # model training notebook
#
# input: engineered features and training configuration.
# expected output: trained model artifacts and training metrics saved under the data/models layer.

# %% [markdown]
# # Quick Start

# %% [markdown]
# config

# %%
from config.settings import AWS_ACCESS_KEY_ID, AWS_SECRET_ACCESS_KEY

storage_options = {
    "key": AWS_ACCESS_KEY_ID,
    "secret": AWS_SECRET_ACCESS_KEY,
}
