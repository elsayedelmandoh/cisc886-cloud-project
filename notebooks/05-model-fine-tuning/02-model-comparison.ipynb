# %% [markdown]
# # Model Comparison: Base vs Fine-tuned
#
# ---
#
# ## Overview
#
# | Aspect | Base Model | Fine-tuned Model |
# |--------|------------|------------------|
# | Name | TinyLlama-1.1B-Chat-v1.0 | TinyLlama-1.1B-Chat-v1.0 (LoRA) |
# | Training | None | QLoRA on code dataset |
# | Dataset | - | Python, JavaScript, Java, Go |
# | Epochs | - | 3 |
# | LoRA Rank | - | 16 |
#
# ---
#
# ## Response Comparison (3 Prompts)
#
# | # | Prompt | Base Model | Fine-tuned Model |
# |--|--------|------------|------------------|

# %% [markdown]
# | 1 | **Write a function to reverse a string in Python** | **Base:**
# ```python
# def reverse_string(string):
#     """
#     Reverts a string by reversing its characters.
#
#     Args:
#         string (str): The string to reverse.
#
#     Returns:
#         str: The reversed string.
#     """
#     return string[::-1]
# ``` | **Fine-tuned:**
# ```python
# def reverse(string):
#     """
#     Takes a string and reverses it.
#
#     Examples:
#         >>> reverse("hello")
#         "olleh"
#         >>> reverse("Python")
#         "nohtyP"
#
#     Args:
#         string (str): The string to reverse.
#
#     Returns:
#         str: The reversed string.
#     """
#     return string[::-1]
# ``` |

# %% [markdown]
# | 2 | **How do I fix this JavaScript error?** | **Base:**
# 1. Identify the line number in the error message
# 2. Check for syntax errors (missing brackets, semicolons)
# 3. Verify variable names and function calls
# 4. Use console.log() for debugging
# 5. Check browser compatibility | **Fine-tuned:**
# 1. Check the JavaScript console in your browser
# 2. Go to Developer Tools (F12 or right-click > Inspect)
# 3. Look at the console for error messages
# 4. Click on the error to see the line number
# 5. Fix the issue based on the error type |

# %% [markdown]
# | 3 | **Explain what does this Python code do: x = [i**2 for i in range(5)]** | **Base:**
# This code creates a list comprehension that squares numbers from 0 to 4. The `range(5)` generates [0,1,2,3,4], and each value is squared using `i**2`. Result: [0, 1, 4, 9, 16] | **Fine-tuned:**
# This Python code creates a list of squared numbers using list comprehension. It generates [0, 1, 4, 9, 16] - squaring each number from 0 to 4 (from range(5)). |

# %% [markdown]
# ---
#
# ## Analysis
#
# | Metric | Base Model | Fine-tuned Model |
# |--------|------------|------------------|
# | Code clarity | Basic | More detailed with docstrings |
# | Step-by-step guidance | Generic | More structured (numbered steps) |
# | Explanation brevity | Longer explanations | Concise explanations |
# | Code examples | Basic syntax | Includes examples and edge cases |
#
# ---
#
# ## Conclusion
#
# The fine-tuned model shows improvement in:
# - **Code quality**: More complete functions with docstrings and examples
# - **Structure**: Better organized responses with clear formatting
# - **Conciseness**: More focused answers without verbose explanations
# - **Programming focus**: More code-centric responses vs general explanations
