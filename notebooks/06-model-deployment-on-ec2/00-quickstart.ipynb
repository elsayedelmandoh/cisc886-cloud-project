# %% [markdown]
# # model evaluation notebook
#
# input: trained model artifacts and evaluation datasets.
# expected output: metrics, plots, and comparison notes that describe model quality.

# %% [markdown]
# # Quick Start
