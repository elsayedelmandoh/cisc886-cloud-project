# %% [markdown]
# # Section 4: Data Preprocessing with Apache Spark on EMR
#
# ---
#
# ## EMR Cluster Configuration
#
# | Setting | Value |
# |---------|-------|
# | Cluster Name | 25xrvl-emr-sg |
# | Instance Type | m5.xlarge (master), m5.xlarge (core) x2 |
# | Number of Nodes | 3 |
# | Region | us-east-1 |
# | Release | emr-7.2.0 |
# | Applications | Spark 3.5, Hadoop 3, JupyterEnterpriseGateway |
#
# ---

# %% [markdown]
# ## PySpark Preprocessing Pipeline
#
# preprocessing script here: `cisc886-cloud-project\src\preprocessing\preprocess_emr.py`

# %% [markdown]
# ---
#
# ## Screenshots Required
#
# > Take the following screenshots for submission:
#
# ### 1. EMR Cluster Configuration
# - Go to: **AWS Console → EMR → Clusters**
# - Screenshot showing:
#   - Cluster name: 25xrvl-emr-sg
#   - Instance type: m5.xlarge
#   - Number of nodes: 3
#   - Region: us-east-1
#   - 04-emr-config-01
# ![04-emr-config-01](04-emr-config-01.jpeg)
#
#   - 04-emr-config-02
# ![04-emr-config-02](04-emr-config-02.jpg)
#
#   - 04-emr-config-03
# ![04-emr-config-03](04-emr-config-03.jpg)
#
#   - 04-emr-config-04
# ![04-emr-config-04](04-emr-config-04.jpg)
#
#   - 04-emr-config-05
# ![04-emr-config-05](04-emr-config-05.jpg)
#
#   - 04-emr-config-06
# ![04-emr-config-06](04-emr-config-06.jpg)

# %% [markdown]
# ### 2. EMR Cluster Terminated (CRITICAL)
# - After processing, terminate the cluster
# - Screenshot showing cluster in **Terminated** state
# - > WARNING: Missing this screenshot = incomplete submission
#   - 04-emr-terminated-01
# ![04-emr-terminated-01](04-emr-terminated-01.png)
#
#   - 04-emr-terminated-02
# ![04-emr-terminated-02](04-emr-terminated-02.png)

# %% [markdown]
# ### 3. S3 Output Files
# - Go to: **AWS Console → S3 → 25xrvl-s3**
# - Navigate to processed/ folder
# - Screenshot showing:
#   - train/ folder
#   - val/ folder
#   - test/ folder
#   - 04-bucket-01
# ![04-bucket-01](04-bucket-01.jpeg)
#
# - 04-bucket-02
# ![04-bucket-02](04-bucket-02.jpeg)
#
# - 04-bucket-03
# ![04-bucket-03](04-bucket-03.jpeg)
#
# - 04-bucket-04
# ![04-bucket-04](04-bucket-04.jpeg)
#
# - 04-bucket-05
# ![04-bucket-05](04-bucket-05.jpeg)
#
# - 04-bucket-06
# ![04-bucket-06](04-bucket-06.jpeg)

# %% [markdown]
# ### 4. EDA Figures (at least 3)
# - Take screenshots of any visualizations from notebook:
#   - Language/label distribution (pie/bar chart)
#   - Token length distribution histogram
#   - Sample count per split bar chart
#   - language_distribution
# ![04_fig_1_language_distribution](04_fig_1_language_distribution.png)
#
#   - token_length_distribution
# ![04_fig_2_token_length_distribution](04_fig_2_token_length_distribution.png)
#
#   - dataset_splits
# ![04_fig_3_dataset_splits](04_fig_3_dataset_splits.png)
