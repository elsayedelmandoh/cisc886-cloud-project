# %% [markdown]
# # feature engineering notebook
#
# input: processed data.
# expected output: feature sets and feature definitions ready for training and evaluation.

# %% [markdown]
# # Feature Engineering
#
# what do we actually hand to the model?
