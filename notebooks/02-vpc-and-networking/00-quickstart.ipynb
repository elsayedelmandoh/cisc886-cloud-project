# %% [markdown]
# # exploratory data analysis notebook
#
# input: raw or processed datasets.
# expected output: charts, tables, and insights that explain the data before preprocessing or modeling.

# %% [markdown]
# # Exploratory Data Analysis - EDA
#
# Before we start coding, we need to genuinely understand the data, to explore through its hidden information. EDA is where we discover whether the task is feasible and how to approach it.
#
# This is a summary of what was done in this notebooks: data quality, class distribution, review length patterns, and the actual vocabulary customers use.
# Every finding here had the potential to be useful for the decision in the preprocessing and modelling stages.
