# %% [markdown]
# # Project Notebook Overview
#
# ## Sections and Code Requirements
#
# | Section | Notebook | Code Required? | Submit |
# |---------|----------|----------------|--------|
# | 1 - System Architecture | 01-architecture.ipynb | No (diagram only) | Architecture diagram + paragraph |
# | 2 - VPC & Networking | 01-vpc-networking.ipynb | **Yes** (Terraform) | Terraform + screenshots |
# | 3 - Model & Dataset Selection | 01-model-dataset-selection.ipynb | **No** | Written report only |
# | 4 - Data Preprocessing with EMR | 01-preprocessing.ipynb | **Yes** | PySpark code + EMR screenshots + EDA |
# | 5 - Model Fine-tuning | 01-fine-tuning.ipynb | **Yes** | Training notebook + comparison |
# | 6 - Model Deployment on EC2 | 01-deployment.ipynb | **Yes** | Terminal screens + curl response |
# | 7 - Web Interface | 01-web-interface.ipynb | **Yes** | Browser screenshots |
#
# ---
#
# ## Quick Reference
#
# **No Code Required:**
# - Section 1: Diagram + paragraph
# - Section 2: Terraform code
# - Section 3: Written report only
#
# **Code Required:**
# - Section 4: PySpark on EMR
# - Section 5: Fine-tuning (Colab)
# - Section 6: EC2 deployment
# - Section 7: OpenWebUI setup
#
# ---
#
# ## Screenshot Requirements
#
# | Section | Screenshots |
# |---------|-------------|
# | 1 | System architecture diagram |
# | 2 | VPC console / Terraform |
# | 4 | EMR config + **Terminated** + S3 output + 3 EDA |
# | 5 | Base vs fine-tuned comparison |
# | 6 | Ollama serving + curl API |
# | 7 | OpenWebUI + conversation |
